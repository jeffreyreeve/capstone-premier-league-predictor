# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import MinMaxScaler
#from ELO import ELO_rating

# %%
# Read in the PL22-23final.csv file from https://www.football-data.co.uk/englandm.php
pd.set_option('display.max_columns', None)
season23 = pd.read_csv('../data/PL22-23final.csv')
season23.head()
# Out:
#   Div      Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0
# 1  E0  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1
# 2  E0  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1
# 3  E0  6/8/2022  15:00           Leeds         Wolves     2     1   H     1
# 4  E0  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0
#
#    HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  \
# 0     1   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0
# 1     0   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0
# 2     0   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0
# 3     1   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0
# 4     0   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0
#
# ...

# %%
season23 = season23.drop(['Div'], axis=1)
season23.head()
# Out:
#        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'HomeTeam': 'H', 'AwayTeam': 'A'}, inplace=True)
season23.head()
# Out:
#        Date   Time               H              A  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'H': 'Team'}, inplace=True)
season23.head()
# Out:
#        Date   Time            Team              A  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
pd.set_option('display.max_columns', None)
teams1 = pd.read_csv('../data/teams23.csv')
teams1.head()
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0   NaN   1     0      Arsenal       0       0         0
# 1     7     0   NaN   2     0  Aston Villa       0       0         0
# 2    91     0   NaN   3     0  Bournemouth       0       0         0
# 3    94     0   NaN   4     0    Brentford       0       0         0
# 4    36     0   NaN   5     0     Brighton       0       0         0
#
#   short_name  strength  team_division  unavailable  win  \
# 0        ARS         4            NaN        False    0
# 1        AVL         3            NaN        False    0
# 2        BOU         2            NaN        False    0
# 3        BRE         3            NaN        False    0
# 4        BHA         3            NaN        False    0
#
#    strength_overall_home  strength_overall_away  strength_attack_home  \
# 0                   1245                   1285                  1250
# ...

# %%
teams1.rename(columns={'name': 'Name'}, inplace=True)
teams1.head()
# Out:
#    code  draw  form  id  loss         Name  played  points  position  \
# 0     3     0   NaN   1     0      Arsenal       0       0         0
# 1     7     0   NaN   2     0  Aston Villa       0       0         0
# 2    91     0   NaN   3     0  Bournemouth       0       0         0
# 3    94     0   NaN   4     0    Brentford       0       0         0
# 4    36     0   NaN   5     0     Brighton       0       0         0
#
#   short_name  strength  team_division  unavailable  win  \
# 0        ARS         4            NaN        False    0
# 1        AVL         3            NaN        False    0
# 2        BOU         2            NaN        False    0
# 3        BRE         3            NaN        False    0
# 4        BHA         3            NaN        False    0
#
#    strength_overall_home  strength_overall_away  strength_attack_home  \
# 0                   1245                   1285                  1250
# ...

# %%
teams1 = teams1.drop(['code', 'draw', 'form', 'id', 'loss', 'played', 'points', 'position', 'short_name', 'team_division', 'unavailable', 'win', 'pulse_id'], axis=1) 
teams1.head()
# Out:
#           Name  strength  strength_overall_home  strength_overall_away  \
# 0      Arsenal         4                   1245                   1285
# 1  Aston Villa         3                   1070                   1100
# 2  Bournemouth         2                   1035                   1095
# 3    Brentford         3                   1115                   1180
# 4     Brighton         3                   1170                   1175
#
#    strength_attack_home  strength_attack_away  strength_defence_home  \
# 0                  1250                  1250                   1240
# 1                  1070                  1075                   1070
# 2                  1020                  1110                   1050
# 3                  1100                  1160                   1130
# 4                  1140                  1150                   1200
#
#    strength_defence_away
# 0                   1320
# 1                   1130
# 2                   1080
# ...

# %%
teams1['Name'] = teams1['Name'].replace('Spurs', 'Tottenham')
teams1
# Out:
#               Name  strength  strength_overall_home  strength_overall_away  \
# 0          Arsenal         4                   1245                   1285
# 1      Aston Villa         3                   1070                   1100
# 2      Bournemouth         2                   1035                   1095
# 3        Brentford         3                   1115                   1180
# 4         Brighton         3                   1170                   1175
# 5          Chelsea         3                   1165                   1220
# 6   Crystal Palace         3                   1085                   1100
# 7          Everton         3                   1055                   1095
# 8           Fulham         3                   1095                   1100
# 9        Leicester         3                   1130                   1115
# 10           Leeds         3                   1100                   1090
# ...

# %%
teams1['Name'] = teams1['Name'].replace('Man Utd', 'Man United')
teams1
# Out:
#               Name  strength  strength_overall_home  strength_overall_away  \
# 0          Arsenal         4                   1245                   1285
# 1      Aston Villa         3                   1070                   1100
# 2      Bournemouth         2                   1035                   1095
# 3        Brentford         3                   1115                   1180
# 4         Brighton         3                   1170                   1175
# 5          Chelsea         3                   1165                   1220
# 6   Crystal Palace         3                   1085                   1100
# 7          Everton         3                   1055                   1095
# 8           Fulham         3                   1095                   1100
# 9        Leicester         3                   1130                   1115
# 10           Leeds         3                   1100                   1090
# ...

# %%
teams1.to_csv('../data/teams1.csv')

# %%
pd.set_option('display.max_columns', None)
teams2 = pd.read_csv('../data/teams_fifa23.csv')
teams2.head()
# Out:
#        ID             Name                      League  LeagueId  Overall  \
# 0    1943  AFC Bournemouth  English Premier League (1)        13       74
# 1  116418     AFC Richmond  English Premier League (1)        13       78
# 2       1          Arsenal  English Premier League (1)        13       80
# 3       2      Aston Villa  English Premier League (1)        13       79
# 4    1925        Brentford  English Premier League (1)        13       75
#
#    Attack  Midfield  Defence  TransferBudget  DomesticPrestige  IntPrestige  \
# 0      75        73       73               0                 2            1
# 1      81        79       77               0                 5            3
# 2      83        81       79               0                 7            7
# 3      79        78       80               0                 5            3
# 4      75        74       75               0                 1            1
#
#    Players  StartingAverageAge  AllTeamAverageAge
# ...

# %%
teams2 = teams2.drop(['ID', 'League', 'LeagueId', 'TransferBudget', 'Players'], axis=1) 
teams2.head()
# Out:
#               Name  Overall  Attack  Midfield  Defence  DomesticPrestige  \
# 0  AFC Bournemouth       74      75        73       73                 2
# 1     AFC Richmond       78      81        79       77                 5
# 2          Arsenal       80      83        81       79                 7
# 3      Aston Villa       79      79        78       80                 5
# 4        Brentford       75      75        74       75                 1
#
#    IntPrestige  StartingAverageAge  AllTeamAverageAge
# 0            1                25.8               25.5
# 1            3                27.3               27.3
# 2            7                24.1               23.0
# 3            3                25.8               25.2
# 4            1                25.4               24.2

# %%
teams2 = teams2.drop(labels=[1], axis=0)

# %%
replacement_dict = {'AFC Bournemouth': 'Bournemouth',
                    'Leeds United': 'Leeds',
                    'Manchester City': 'Man City',
                    'Manchester United': 'Man United',
                    'Nottingham Forest': "Nott'm Forest",
                    'Wolverhampton Wanderers': 'Wolves',
                    'Brighton & Hove Albion': 'Brighton',
                    'Leicester City': 'Leicester',
                    'Newcastle United': 'Newcastle',
                    'Tottenham Hotspur': 'Tottenham',
                    'West Ham United': 'West Ham'}

# Replace the values in the 'Name' column using the dictionary
teams2['Name'] = teams2['Name'].replace(replacement_dict)
teams2
# Out:
#                              Name  Overall  Attack  Midfield  Defence  \
# 0                     Bournemouth       74      75        73       73
# 2                         Arsenal       80      83        81       79
# 3                     Aston Villa       79      79        78       80
# 4                       Brentford       75      75        74       75
# 5                        Brighton       76      76        75       77
# ..                            ...      ...     ...       ...      ...
# 673        Deportivo La Guaira FC       65      64        65       65
# 674          Deportivo Táchira FC       65      66        66       65
# 675         Estudiantes de Mérida       65      64        65       64
# 676           Hermanos Colmenarez       65      66        64       65
# 677  Metropolitanos de Caracas FC       65      65        66       65
#
#      DomesticPrestige  IntPrestige  StartingAverageAge  AllTeamAverageAge
# ...

# %%
teams2 =teams2.truncate(after=20)
teams2
# Out:
#               Name  Overall  Attack  Midfield  Defence  DomesticPrestige  \
# 0      Bournemouth       74      75        73       73                 2
# 2          Arsenal       80      83        81       79                 7
# 3      Aston Villa       79      79        78       80                 5
# 4        Brentford       75      75        74       75                 1
# 5         Brighton       76      76        75       77                 3
# 6          Chelsea       84      84        86       84                 9
# 7   Crystal Palace       76      77        75       76                 4
# 8          Everton       78      80        77       75                 4
# 9           Fulham       76      78        76       74                 2
# 10           Leeds       76      78        76       76                 3
# 11       Leicester       79      81        80       78                 6
# 12       Liverpool       85      84        82       87                 9
# ...

# %%
teams2.to_csv('../data/teams2.csv')

# %%
pd.set_option('display.max_columns', None)
fbref = pd.read_csv('../data/fbref.csv')
fbref.head()
# Out:
#           Team   Gls  Assts  GlsPK    xG  NpxG   xAG  Poss  PrgC  PrgP  GKS%  \
# 0      Arsenal  2.14   1.62   2.05  1.87  1.79  1.39  59.5  21.7  54.2  70.6
# 1  Aston Villa  1.27   0.89   1.19  1.28  1.20  0.98  49.5  16.7  32.8  72.8
# 2  Bournemouth  1.00   0.65   1.00  1.03  1.03  0.76  39.8  13.2  26.1  67.7
# 3    Brentford  1.49   0.95   1.30  1.50  1.33  1.02  44.1  10.2  30.2  77.4
# 4     Brighton  1.81   1.22   1.65  1.94  1.83  1.39  60.3  21.4  49.1  64.3
#
#    GKCS%   SoT  G-xG    Cmp  Cmp%  PrgDist    Xa     KP    PPA  CrsPA    TB  \
# 0   35.1  5.03  0.27  482.8  83.1   2658.9  1.21  11.70  12.01   1.65  2.24
# 1   32.4  3.78 -0.01  363.3  79.3   2320.0  0.81   8.38   7.08   2.11  1.38
# 2   21.6  3.38 -0.03  303.8  75.9   2159.2  0.70   6.92   6.27   1.97  1.30
# 3   29.7  3.86 -0.01  298.5  72.7   2294.1  0.79   7.46   7.32   2.30  1.43
# 4   32.4  5.81 -0.13  509.1  84.0   2811.5  1.18  12.80  10.50   2.05  2.08
#
# ...

# %%
fbref.rename(columns={'Team': 'Name'}, inplace=True)
fbref.head()
# Out:
#           Name   Gls  Assts  GlsPK    xG  NpxG   xAG  Poss  PrgC  PrgP  GKS%  \
# 0      Arsenal  2.14   1.62   2.05  1.87  1.79  1.39  59.5  21.7  54.2  70.6
# 1  Aston Villa  1.27   0.89   1.19  1.28  1.20  0.98  49.5  16.7  32.8  72.8
# 2  Bournemouth  1.00   0.65   1.00  1.03  1.03  0.76  39.8  13.2  26.1  67.7
# 3    Brentford  1.49   0.95   1.30  1.50  1.33  1.02  44.1  10.2  30.2  77.4
# 4     Brighton  1.81   1.22   1.65  1.94  1.83  1.39  60.3  21.4  49.1  64.3
#
#    GKCS%   SoT  G-xG    Cmp  Cmp%  PrgDist    Xa     KP    PPA  CrsPA    TB  \
# 0   35.1  5.03  0.27  482.8  83.1   2658.9  1.21  11.70  12.01   1.65  2.24
# 1   32.4  3.78 -0.01  363.3  79.3   2320.0  0.81   8.38   7.08   2.11  1.38
# 2   21.6  3.38 -0.03  303.8  75.9   2159.2  0.70   6.92   6.27   1.97  1.30
# 3   29.7  3.86 -0.01  298.5  72.7   2294.1  0.79   7.46   7.32   2.30  1.43
# 4   32.4  5.81 -0.13  509.1  84.0   2811.5  1.18  12.80  10.50   2.05  2.08
#
# ...

# %%
fbref
# Out:
#               Name   Gls  Assts  GlsPK    xG  NpxG   xAG  Poss  PrgC  PrgP  \
# 0          Arsenal  2.14   1.62   2.05  1.87  1.79  1.39  59.5  21.7  54.2
# 1      Aston Villa  1.27   0.89   1.19  1.28  1.20  0.98  49.5  16.7  32.8
# 2      Bournemouth  1.00   0.65   1.00  1.03  1.03  0.76  39.8  13.2  26.1
# 3        Brentford  1.49   0.95   1.30  1.50  1.33  1.02  44.1  10.2  30.2
# 4         Brighton  1.81   1.22   1.65  1.94  1.83  1.39  60.3  21.4  49.1
# 5          Chelsea  1.00   0.73   0.92  1.28  1.22  0.99  58.5  21.4  45.5
# 6   Crystal Palace  1.00   0.76   0.97  1.02  0.96  0.75  45.8  14.2  32.2
# 7         Everton   0.84   0.65   1.26  1.19  1.13  0.86  42.9  13.0  27.6
# 8           Fulham  1.38   0.86   0.74  1.20  1.03  0.75  48.8  17.3  35.2
# 9            Leeds  1.19   0.81   1.16  1.24  1.18  0.83  46.8  14.4  37.1
# 10       Leicester  1.27   0.92   1.19  1.33  1.20  1.01  47.7  15.2  34.3
# ...

# %%
fbref =fbref.truncate(after=19)
fbref
# Out:
#               Name   Gls  Assts  GlsPK    xG  NpxG   xAG  Poss  PrgC  PrgP  \
# 0          Arsenal  2.14   1.62   2.05  1.87  1.79  1.39  59.5  21.7  54.2
# 1      Aston Villa  1.27   0.89   1.19  1.28  1.20  0.98  49.5  16.7  32.8
# 2      Bournemouth  1.00   0.65   1.00  1.03  1.03  0.76  39.8  13.2  26.1
# 3        Brentford  1.49   0.95   1.30  1.50  1.33  1.02  44.1  10.2  30.2
# 4         Brighton  1.81   1.22   1.65  1.94  1.83  1.39  60.3  21.4  49.1
# 5          Chelsea  1.00   0.73   0.92  1.28  1.22  0.99  58.5  21.4  45.5
# 6   Crystal Palace  1.00   0.76   0.97  1.02  0.96  0.75  45.8  14.2  32.2
# 7         Everton   0.84   0.65   1.26  1.19  1.13  0.86  42.9  13.0  27.6
# 8           Fulham  1.38   0.86   0.74  1.20  1.03  0.75  48.8  17.3  35.2
# 9            Leeds  1.19   0.81   1.16  1.24  1.18  0.83  46.8  14.4  37.1
# 10       Leicester  1.27   0.92   1.19  1.33  1.20  1.01  47.7  15.2  34.3
# ...

# %%
fbref.to_csv('../data/fbrefNew.csv')

# %%
team_data = pd.merge(teams1, teams2, on='Name', how='left')
team_data = pd.merge(team_data, fbref, on='Name', how='left')
team_data.head()
# Out:
#           Name  strength  strength_overall_home  strength_overall_away  \
# 0      Arsenal         4                   1245                   1285
# 1  Aston Villa         3                   1070                   1100
# 2  Bournemouth         2                   1035                   1095
# 3    Brentford         3                   1115                   1180
# 4     Brighton         3                   1170                   1175
#
#    strength_attack_home  strength_attack_away  strength_defence_home  \
# 0                  1250                  1250                   1240
# 1                  1070                  1075                   1070
# 2                  1020                  1110                   1050
# 3                  1100                  1160                   1130
# 4                  1140                  1150                   1200
#
#    strength_defence_away  Overall  Attack  Midfield  Defence  \
# ...

# %%
team_data
# Out:
#               Name  strength  strength_overall_home  strength_overall_away  \
# 0          Arsenal         4                   1245                   1285
# 1      Aston Villa         3                   1070                   1100
# 2      Bournemouth         2                   1035                   1095
# 3        Brentford         3                   1115                   1180
# 4         Brighton         3                   1170                   1175
# 5          Chelsea         3                   1165                   1220
# 6   Crystal Palace         3                   1085                   1100
# 7          Everton         3                   1055                   1095
# 8           Fulham         3                   1095                   1100
# 9        Leicester         3                   1130                   1115
# 10           Leeds         3                   1100                   1090
# ...

# %%
team_data.rename(columns={'strength': 'Str', 'strength_overall_home': 'SOH', 'strength_overall_away': 'SOA', 'strength_attack_home': 'SAH', 'strength_attack_away': 'SAA', 'strength_defence_home': 'SDH', 'strength_defence_away': 'SDA', 'Overall': 'O', 'Attack': 'A', 'Midfield': 'M', 'Defence': 'D', 'DomesticPrestige': 'DP', 'IntPrestige': 'IP', 'StartingAverageAge': 'SAAg', 'AllTeamAverageAge': 'ATAAg'}, inplace=True)
team_data.head()
# Out:
#           Name  Str   SOH   SOA   SAH   SAA   SDH   SDA   O   A   M   D  DP  \
# 0      Arsenal    4  1245  1285  1250  1250  1240  1320  80  83  81  79   7
# 1  Aston Villa    3  1070  1100  1070  1075  1070  1130  79  79  78  80   5
# 2  Bournemouth    2  1035  1095  1020  1110  1050  1080  74  75  73  73   2
# 3    Brentford    3  1115  1180  1100  1160  1130  1200  75  75  74  75   1
# 4     Brighton    3  1170  1175  1140  1150  1200  1200  76  76  75  77   3
#
#    IP  SAAg  ATAAg   Gls  Assts  GlsPK    xG  NpxG   xAG  Poss  PrgC  PrgP  \
# 0   7  24.1   23.0  2.14   1.62   2.05  1.87  1.79  1.39  59.5  21.7  54.2
# 1   3  25.8   25.2  1.27   0.89   1.19  1.28  1.20  0.98  49.5  16.7  32.8
# 2   1  25.8   25.5  1.00   0.65   1.00  1.03  1.03  0.76  39.8  13.2  26.1
# 3   1  25.4   24.2  1.49   0.95   1.30  1.50  1.33  1.02  44.1  10.2  30.2
# 4   2  27.6   23.6  1.81   1.22   1.65  1.94  1.83  1.39  60.3  21.4  49.1
#
# ...

# %%
team_data.rename(columns={'Name': 'Team', 'Dis': 'Dist'}, inplace=True)
team_data.head()
# Out:
#           Team  Str   SOH   SOA   SAH   SAA   SDH   SDA   O   A   M   D  DP  \
# 0      Arsenal    4  1245  1285  1250  1250  1240  1320  80  83  81  79   7
# 1  Aston Villa    3  1070  1100  1070  1075  1070  1130  79  79  78  80   5
# 2  Bournemouth    2  1035  1095  1020  1110  1050  1080  74  75  73  73   2
# 3    Brentford    3  1115  1180  1100  1160  1130  1200  75  75  74  75   1
# 4     Brighton    3  1170  1175  1140  1150  1200  1200  76  76  75  77   3
#
#    IP  SAAg  ATAAg   Gls  Assts  GlsPK    xG  NpxG   xAG  Poss  PrgC  PrgP  \
# 0   7  24.1   23.0  2.14   1.62   2.05  1.87  1.79  1.39  59.5  21.7  54.2
# 1   3  25.8   25.2  1.27   0.89   1.19  1.28  1.20  0.98  49.5  16.7  32.8
# 2   1  25.8   25.5  1.00   0.65   1.00  1.03  1.03  0.76  39.8  13.2  26.1
# 3   1  25.4   24.2  1.49   0.95   1.30  1.50  1.33  1.02  44.1  10.2  30.2
# 4   2  27.6   23.6  1.81   1.22   1.65  1.94  1.83  1.39  60.3  21.4  49.1
#
# ...

# %%
#team_data.to_csv('team_data.csv')

# %%
season23 = pd.merge(season23, team_data, on='Team', how='left')
season23.head()
# Out:
#        Date   Time            Team            A_x  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'Team': 'TeamH', 'A_x': 'TeamA', 'A_y': 'A'}, inplace=True)
season23.head()
# Out:
#        Date   Time           TeamH          TeamA  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'Str': 'HStr', 'SOH': 'HSOH', 'SOA': 'HSOA', 'SAG': 'HSAH', 'SAA': 'HSAA', 'SDH': 'HSDH', 'SDA': 'HSDA', 'O': 'HO', 'A': 'HA', 'M': 'HM', 'D': 'HD', 'StartingAverageAge': 'HSAAge', 'Gls': 'HGls', 'Assts': 'HAssts', 'GlsPK': 'HGlsPK', 'xG': 'HxG', 'NpxG': 'HNpxG', 'xAG': 'HxAG', 'Poss': 'HPoss', 'PrgC': 'HPrg', 'PrgP': 'HPrgP', 'GKS%': 'HGKS%', 'GKCS%': 'HGKCS%', 'SoT': 'HSoT', 'G-xG': 'Hg-xG', 'Cmp': 'HCmp', 'Cmp%': 'HCmp%', 'PrgDist': 'HPrgDist', 'Xa': 'HXa', 'KP': 'HKP', 'PPA': 'HPPA', 'CrsPA': 'HCrsPA', 'TB': 'HTB', 'Crs': 'HCrs', 'CK': 'HCK', 'SCA': 'HSCA', 'GCA': 'HGCA', 'TkIW': 'TkIW', 'Lost': 'HLost', 'Blocks': 'HBlocks', 'Pass': 'HPass', 'Int': 'HInt', 'Clr': 'HClr', 'AttPen': 'HAttPen', 'Succ%': 'HSucc%', 'CPA': 'HCPA', 'Dis': 'HDis', 'PrgR': 'HPrgR', 'OnG': 'HOnG', 'OnGA': 'HOnGA', 'OnxG': 'HOnxG', 'OnxGA': 'HOnxGA'}, inplace=True)
season23.head()
# Out:
#        Date   Time           TeamH           Team  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'TeamA': 'Team', 'Dis ': 'HDis'}, inplace=True)
season23.head()
# Out:
#        Date   Time           TeamH           Team  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'SAH': 'HSAH'}, inplace=True)
season23.head()
# Out:
#        Date   Time           TeamH           Team  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23 = pd.merge(season23, team_data, on='Team', how='left')
season23.head()
# Out:
#        Date   Time           TeamH           Team  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'Team': 'TeamA', 'DP_x': 'HDP', 'IP_x': 'HIP', 'SAAg_x': 'HSAAg', 'ATAAg_x': 'HATAAg', 'TkIW_x': 'HTkIW', 'Str': 'AStr', 'SOH': 'ASOH', 'SOA': 'ASOA', 'SAH': 'ASAH', 'SAA': 'ASAA', 'SDH': 'ASDH', 'SDA': 'ASDA', 'O': 'AO', 'A': 'AA', 'M': 'AM', 'D': 'AD', 'DP_y': 'ADP', 'IP_y': 'AIP', 'SAAg_y': 'ASAAg', 'ATAAg_y': 'ATAAg', 'Gls': 'AGls', 'Assts': 'AAssts', 'GlsPK': 'AGlsPK', 'xG': 'AxG', 'NpxG': 'ANpxG', 'xAG': 'AxAG', 'Poss': 'APoss', 'PrgC': 'APrg', 'PrgP': 'APrgP', 'GKS%': 'AGKS%', 'GKCS%': 'AGKCS%', 'SoT': 'ASoT', 'G-xG': 'Ag-xG', 'Cmp': 'ACmp', 'Cmp%': 'ACmp%', 'PrgDist': 'APrgDist', 'Xa': 'AXa', 'KP': 'AKP', 'PPA': 'APPA', 'CrsPA': 'ACrsPA', 'TB': 'ATB', 'Crs': 'ACrs', 'CK': 'ACK', 'SCA': 'ASCA', 'GCA': 'AGCA', 'TkIW_y': 'ATkIW', 'Lost': 'ALost', 'Blocks': 'ABlocks', 'Pass': 'APass', 'Int': 'AInt', 'Clr': 'AClr', 'AttPen': 'AAttPen', 'Succ%': 'ASucc%', 'CPA': 'ACPA', 'PrgR': 'APrgR', 'OnG': 'AOnG', 'OnGA': 'AOnGA', 'OnxG': 'AOnxG', 'OnxGA': 'AOnxGA'}, inplace=True)
season23.head()
# Out:
#        Date   Time           TeamH          TeamA  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23.rename(columns={'Dis ': 'ADis'}, inplace=True)
season23.head()
# Out:
#        Date   Time           TeamH          TeamA  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0     1
# 1  6/8/2022  12:30          Fulham      Liverpool     2     2   D     1     0
# 2  6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1     0
# 3  6/8/2022  15:00           Leeds         Wolves     2     1   H     1     1
# 4  6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0     0
#
#   HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# 0   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0   4.20
# 1   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  11.00
# 2   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0   3.75
# 3   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0   2.25
# 4   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0   1.66
#
# ...

# %%
season23
# Out:
#            Date   Time           TeamH          TeamA  FTHG  FTAG FTR  HTHG  \
# 0      5/8/2022  20:00  Crystal Palace        Arsenal     0     2   A     0
# 1      6/8/2022  12:30          Fulham      Liverpool     2     2   D     1
# 2      6/8/2022  15:00     Bournemouth    Aston Villa     2     0   H     1
# 3      6/8/2022  15:00           Leeds         Wolves     2     1   H     1
# 4      6/8/2022  15:00       Newcastle  Nott'm Forest     2     0   H     0
# ..          ...    ...             ...            ...   ...   ...  ..   ...
# 375  28/05/2023  16:30         Everton    Bournemouth     1     0   H     0
# 376  28/05/2023  16:30           Leeds      Tottenham     1     4   A     0
# 377  28/05/2023  16:30       Leicester       West Ham     2     1   H     1
# 378  28/05/2023  16:30      Man United         Fulham     2     1   H     1
# 379  28/05/2023  16:30     Southampton      Liverpool     4     4   D     2
#
# ...

# %%
season23.to_csv('../data/season23new2.csv')

# %%
# I thought I had this date completely clean but I noticed a problem with Everton merging into final dataframe (aaahhh!!!). Will ask for help on this in class tomorrow.

# %%
# Create a new DataFrame to store the transformed data
new_df = pd.DataFrame(columns=['Date', 'Time', 'TeamH', 'FTHG', 'HTHG', 'HS', 'HST', 'HF', 'HC', 'HY', 'HR'])

# Iterate over the rows of the original DataFrame
for _, row in season23.iterrows():
    date = row['Date']
    time = row['Time']
    home_team = row['TeamH']
    away_team = row['TeamA']
    fthg = row['FTHG']
    hthg = row['HTHG']
    hs = row['HS']
    hst = row['HST']
    hf = row['HF']
    hc = row['HC']
    hy = row['HY']
    hr = row['HR']

    # Append a new row for the home team
    new_df = new_df.append({'Date': date, 'Time': time, 'TeamH': home_team, 'FTHG': fthg, 'HTHG': hthg, 'HS': hs, 'HST': hst,
                            'HF': hf, 'HC': hc, 'HY': hy, 'HR': hr}, ignore_index=True)

    # Append a new row for the away team
    new_df = new_df.append({'Date': date, 'Time': time, 'TeamH': away_team, 'FTHG': row['FTAG'], 'HTHG': row['HTAG'],
                            'HS': row['AS'], 'HST': row['AST'], 'HF': row['AF'], 'HC': row['AC'],
                            'HY': row['AY'], 'HR': row['AR']}, ignore_index=True)

# Print the transformed DataFrame
new_df

# %%
new_df.rename(columns={'TeamH': 'Team', 'FTHG': 'FTG', 'HTHG': 'HTG', 'HS': 'S', 'HST': 'ST', 'HF': 'F', 'HC': 'C', 'HY': 'Y', 'HR': 'R'}, inplace=True)
new_df.head()

# %%
new_df

# %%
new_df.to_csv('new_df.csv')

# %%
season23_cleaning = season23.drop(['TeamH', 'TeamA', 'FTHG', 'FTAG', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR'], axis=1)
season23_cleaning

# %%
season23_cleaning = season23_cleaning.loc[season23_cleaning.index.repeat(2)].sort_index().reset_index(drop=True)
season23_cleaning

# %%
season23_cleaning.to_csv('season23_cleaning.csv')

# %%
season23_merged = pd.merge(new_df, season23_cleaning, on=['Date', 'Time'], how='left')
season23_merged

# %%
season23_merged = season23_merged.drop_duplicates()
season23_merged

# %%
pd.set_option('display.max_columns', None)
merged = pd.read_csv('../data/merged.csv')
merged.head()

# %%
merged.tail()

# %%
merged

# %%
pd.set_option('display.max_columns', None)
teams1 = pd.read_csv('../data/teams23.csv')
teams1.head()

# %%
teams1.rename(columns={'name': 'Name'}, inplace=True)
teams1.head()

# %%
teams1 = teams1.drop(['code', 'draw', 'form', 'id', 'loss', 'played', 'points', 'position', 'short_name', 'team_division', 'unavailable', 'win', 'pulse_id'], axis=1) 
teams1.head()

# %%
pd.set_option('display.max_columns', None)
teams2 = pd.read_csv('../data/teams_fifa23.csv')
teams2.head()

# %%
teams2 = teams2.drop(['ID', 'League', 'LeagueId', 'TransferBudget', 'DomesticPrestige', 'IntPrestige', 'Players', 'AllTeamAverageAge'], axis=1) 
teams2.head()

# %%
teams2 = teams2.drop(labels=[1], axis=0)

# %%
teams2['Name'] = teams2['Name'].replace('AFC Bournemouth', 'Bournemouth')
teams2.head()

# %%
pd.set_option('display.max_columns', None)
fbref = pd.read_csv('../data/fbref.csv')
fbref.head()

# %%
fbref.rename(columns={'Team': 'Name'}, inplace=True)
fbref.head()

# %%
team_data = pd.merge(teams1, teams2, on='Name', how='left')
team_data = pd.merge(team_data, fbref, on='Name', how='left')
team_data.head()

# %%
team_data.rename(columns={'Name': 'Team'}, inplace=True)
team_data.head()

# %%
team_data

# %%
team_data.rename(columns={'strength': 'Str', 'strength_overall_home': 'SOH', 'strength_overall_away': 'SOA', 'strength_attack_home': 'SAH', 'strength_attack_away': 'SAA', 'strength_defence_home': 'SDH', 'strength_defence_away': 'SDA', 'Overall': 'O', 'Attack': 'A', 'Midfield': 'M', 'Defence': 'D', 'StartingAverageAge': 'SAA'}, inplace=True)
team_data.head()

# %%
merged1 = pd.merge(merged, team_data, on='Team', how='left')
merged1

# %%
merged1.rename(columns={'strength': 'Str', 'strength_overall_home': 'SOH', 'strength_overall_away': 'SOA', 'strength_attack_home': 'SAH', 'strength_attack_away': 'SAA', 'strength_defence_home': 'SDH', 'strength_defence_away': 'SDA'}, inplace=True)
merged1.head()

# %%
merged1.rename(columns={'Overall': 'O', 'Attack': 'A', 'Midfield': 'M', 'Defence': 'D', 'StartingAverageAge': 'SAA'}, inplace=True)
merged1.head()

# %%
merged1

# %%
np.repeat(range(1, len(merged1) + 1), 2)

# Add a new column at the beginning with repeating values
merged1.insert(0, 'Match #', repeating_values)
merged1.head()

# %%
#import os
#import re
#import time 
#path = '../../Fantasy-Premier-League/data/2022-23/'
#understats_columns = ['xG','xGA','ppda','date']
#team_understats = {}
#files = sorted(os.listdir(path+'understat/'))[1:]
#for idx,file in enumerate(files):
 #   row = pd.read_csv(path+'understat/'+file)[understats_columns]
  #  for loc in range(row.shape[0]):
   #     nums = re.findall(r'\d+', row['ppda'].loc[loc])
    #    res = int(nums[0]) / int(nums[1])
     #   row['ppda'].loc[loc] = res
    #team_understats[teams[idx]] = row
#team_understats

# %%
#type(team_understats)

# %%
#teams = season23['HomeTeam'].unique()
#teams = sorted(teams)
#print(teams)

# %%
#team_understat = pd.concat(team_understats.values(), ignore_index=True)
#team_understat.head()
